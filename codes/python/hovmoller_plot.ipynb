# %%
from fileIO import *
from constants import *
import numpy as np
import matplotlib.pyplot as plt

sim = CuDiscModel("../outputs/1Ddisc_Lenz_a2")

g = sim.grid
Sig_g, Sig_d, v_d, v_g = sim.load1Drun()

plt.imshow(Sig_g, norm="log", vmin=1.0e-6)
plt.colorbar()

plt.xticks(np.linspace(0.0, 300.0, num=5, endpoint=True), np.logspace(-1, 3, num=5, endpoint=True))
plt.yticks(np.linspace(0.0, 20.0, num=5, endpoint=True), np.linspace(0.0, 1.0, num=5, endpoint=True))
plt.xlabel("Distance from star (au)")
plt.ylabel("Time (Myr)")
plt.title("Gas surface density profile")
plt.gca().set_aspect(10)
plt.show()

plt.imshow(Sig_d, norm="log", vmin=1.0e-6)
plt.colorbar()

plt.xticks(np.linspace(0.0, 300.0, num=5, endpoint=True), np.logspace(-1, 3, num=5, endpoint=True))
plt.yticks(np.linspace(0.0, 20.0, num=5, endpoint=True), np.linspace(0.0, 1.0, num=5, endpoint=True))
plt.xlabel("Distance from star (au)")
plt.ylabel("Time (Myr)")
plt.title("Dust surface density profile")
plt.gca().set_aspect(10)
plt.show()
# Out:
# /u/srwmills/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
